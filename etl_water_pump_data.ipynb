# %%
# Import our dependencies
import pandas as pd
import matplotlib as plt
import numpy as np
import math
import time
import sqlite3

# %% [markdown]
# ## Add additional population and closest cities data to Tanzania Water Pump data file

# %%
# define column names for text file mapping
colNames = ['geonameid','name','asciiname','alternatenames',
           'latitude','longitude','feature class', 'feature code',
           'country code', 'cc2', 'admin1 code', 'admin2 code',
           'admin3 code', 'admin4 code', 'population', 'elevation',
           'dem', 'timezone', 'modification_date']

# %%
# load supplemental data into pandas
pop_df = pd.read_table('./Resources/population_data/TZ.txt', header=None)
pop_df.columns = colNames
pop_df.sort_values(by='population', ascending=False)
# Out:
#        geonameid                         name                    asciiname  \
# 930       149590  United Republic of Tanzania  United Republic of Tanzania
# 11530     160260         Dar es Salaam Region         Dar es Salaam Region
# 3545      152219                Mwanza Region                Mwanza Region
# 5683      154375                 Mbeya Region                 Mbeya Region
# 11533     160263                Dar es Salaam                Dar es Salaam
# ...          ...                          ...                          ...
# 6524      155223                      Majombe                      Majombe
# 6523      155222                      Majonjo                      Majonjo
# 6522      155221                      Majonjo                      Majonjo
# 6521      155220                     Makaange                     Makaange
# 19353   11952724          Galanos Hot Springs          Galanos Hot Springs
#
#                                           alternatenames  latitude  longitude  \
# 930    An Tansain,An Tansáin,Orileede Tansania,Orílẹ́...  -6.00000   35.00000
# 11530   Dar es Salaam,Dar es Salaam Region,Dar-es-Salaam  -6.83523   39.19597
# 3545                 Mkoa wa Mwanza,Mwanza,Mwanza Region  -2.75000   33.08333
# 5683                    Mbeya,Mbeya Region,Mkoa wa Mbeya  -8.20000   33.33333
# 11533  DAR,Dar Es Salaam,Dar Es Salam,Dar es Salaam,D...  -6.82349   39.26951
# ...                                                  ...       ...        ...
# 6524                                                 NaN  -8.83333   33.96667
# 6523                                                 NaN  -5.08333   39.06667
# 6522                                                 NaN  -5.20000   39.03333
# 6521                                                 NaN  -5.21667   39.75000
# 19353         Thermes piges Galanou,Θερμές πηγές Γαλάνου  -5.04364   39.05663
#
#       feature class feature code country code  cc2  admin1 code  admin2 code  \
# 930               A         PCLI           TZ  NaN          0.0          NaN
# 11530             A         ADM1           TZ  NaN         23.0          NaN
# 3545              A         ADM1           TZ  NaN         12.0          NaN
# 5683              A         ADM1           TZ  NaN          9.0          NaN
# 11533             P         PPLA           TZ  NaN         23.0        702.0
# ...             ...          ...          ...  ...          ...          ...
# 6524              P          PPL           TZ  NaN          9.0       1207.0
# 6523              P          PPL           TZ  NaN         18.0        404.0
# 6522              P          PPL           TZ  NaN         18.0        404.0
# 6521              P          PPL           TZ  NaN         20.0       5501.0
# 19353             H         SPNT           TZ  NaN          NaN          NaN
#
#        admin3 code  admin4 code  population  elevation   dem  \
# 930            NaN          NaN    56318348        NaN   829
# 11530          NaN          NaN     2791063        NaN    62
# 3545           NaN          NaN     2772509        NaN  1206
# 5683           NaN          NaN     2707410        NaN  1315
# 11533     702132.0          NaN     2698652        NaN    24
# ...            ...          ...         ...        ...   ...
# 6524     1207171.0          NaN           0        NaN  1214
# 6523      404032.0          NaN           0        NaN    49
# 6522      404151.0          NaN           0        NaN    59
# 6521     5501181.0          NaN           0        NaN    41
# 19353          NaN          NaN           0        NaN    16
#
#                    timezone modification_date
# 930    Africa/Dar_es_Salaam        2020-03-29
# 11530  Africa/Dar_es_Salaam        2011-03-17
# 3545   Africa/Dar_es_Salaam        2015-05-04
# 5683   Africa/Dar_es_Salaam        2015-05-04
# 11533  Africa/Dar_es_Salaam        2019-09-05
# ...                     ...               ...
# 6524   Africa/Dar_es_Salaam        2016-07-26
# 6523   Africa/Dar_es_Salaam        2016-07-26
# 6522   Africa/Dar_es_Salaam        2016-07-26
# 6521   Africa/Dar_es_Salaam        2016-07-26
# 19353  Africa/Dar_es_Salaam        2018-10-01
#
# [19354 rows x 19 columns]

# %%
# subset data to include just city level data (admin3 code) and greater than 0 population for ranking
city_pop_df = pop_df[pop_df['admin3 code'].notnull()]
city_pop_df = city_pop_df[city_pop_df['population']>0]

# Create a combined column with lat/lon
city_pop_df['geo_loc'] = city_pop_df[['latitude','longitude']].values.tolist()

city_pop_df.sort_values(by='population', ascending=False)
# Out:
#        geonameid                 name            asciiname  \
# 11533     160263        Dar es Salaam        Dar es Salaam
# 536       149193  Unguja Ukuu Kaebona  Unguja Ukuu Kaebona
# 73        148726      Zanzibar Island      Zanzibar Island
# 3549      152224               Mwanza               Mwanza
# 77        148730             Zanzibar             Zanzibar
# ...          ...                  ...                  ...
# 7880      156588          Koani Ndogo          Koani Ndogo
# 7881      156589                Koani                Koani
# 3050      151720              Nganane              Nganane
# 14350    6615413   Hadzabe encampment   Hadzabe encampment
# 19346   11822796        W. K. Kikwasi        W. K. Kikwasi
#
#                                           alternatenames  latitude  longitude  \
# 11533  DAR,Dar Es Salaam,Dar Es Salam,Dar es Salaam,D...  -6.82349   39.26951
# 536                      Unguja Ukuu,Unguja Ukuu Kaebona  -6.27452   39.37486
# 73     Ile de Zanzibar,Menuthias,Unguja,Unguja Island...  -6.15557   39.34170
# 3549   MWZ,Muansa,Muanza,Muvanzo,Mvanza,Mwamza,Mwansa...  -2.51667   32.90000
# 77     Ilu Zanzibar,Poli tis Zanzivaris,Sansibar,Sans...  -6.16394   39.19793
# ...                                                  ...       ...        ...
# 7880                                         Koani Ndogo  -6.13333   39.28333
# 7881                                               Koani  -6.13333   39.28333
# 3050                                                 NaN  -6.40000   39.55000
# 14350                                                NaN  -3.52810   35.43537
# 19346                                                NaN  -6.90729   39.16798
#
#       feature class feature code country code  cc2  admin1 code  admin2 code  \
# 11533             P         PPLA           TZ  NaN         23.0        702.0
# 536               A         ADM3           TZ  NaN         21.0       5201.0
# 73                T          ISL           TZ  NaN         21.0       5201.0
# 3549              P         PPLA           TZ  NaN         12.0       1903.0
# 77                P         PPLA           TZ  NaN         25.0       5302.0
# ...             ...          ...          ...  ...          ...          ...
# 7880              P          PPL           TZ  NaN         21.0       5201.0
# 7881              P         PPLA           TZ  NaN         21.0       5201.0
# 3050              P          PPL           TZ  NaN         21.0       5202.0
# 14350             S         HUTS           TZ  NaN         26.0        204.0
# 19346             S         BLDG           TZ  NaN         23.0        702.0
#
#        admin3 code  admin4 code  population  elevation   dem  \
# 11533     702132.0          NaN     2698652        NaN    24
# 536      5201381.0          NaN     1060416        NaN    32
# 73       5201181.0          NaN      896721        NaN    39
# 3549     1903042.0          NaN      436801        NaN  1144
# 77       5302272.0          NaN      403658        NaN    14
# ...            ...          ...         ...        ...   ...
# 7880     5201093.0          NaN        2311        NaN    44
# 7881     5201093.0          NaN        2211        NaN    44
# 3050     5202041.0          NaN        1929        NaN    31
# 14350     204061.0          NaN          20        NaN  1135
# 19346     702232.0          NaN           8        NaN    64
#
#                    timezone modification_date               geo_loc
# 11533  Africa/Dar_es_Salaam        2019-09-05  [-6.82349, 39.26951]
# 536    Africa/Dar_es_Salaam        2016-07-25  [-6.27452, 39.37486]
# 73     Africa/Dar_es_Salaam        2019-04-13   [-6.15557, 39.3417]
# 3549   Africa/Dar_es_Salaam        2019-09-05      [-2.51667, 32.9]
# 77     Africa/Dar_es_Salaam        2019-09-05  [-6.16394, 39.19793]
# ...                     ...               ...                   ...
# 7880   Africa/Dar_es_Salaam        2018-12-04  [-6.13333, 39.28333]
# 7881   Africa/Dar_es_Salaam        2016-07-26  [-6.13333, 39.28333]
# 3050   Africa/Dar_es_Salaam        2016-07-26         [-6.4, 39.55]
# 14350  Africa/Dar_es_Salaam        2016-07-26   [-3.5281, 35.43537]
# 19346  Africa/Dar_es_Salaam        2018-03-10  [-6.90729, 39.16798]
#
# [280 rows x 20 columns]

# %%
# Define function to calculate distance between two GPS points - return distance in km

import math

def haversine(coord1, coord2):
    R = 6372800  # Earth radius in meters
    lat1, lon1 = coord1
    lat2, lon2 = coord2
    
    phi1, phi2 = math.radians(lat1), math.radians(lat2) 
    dphi       = math.radians(lat2 - lat1)
    dlambda    = math.radians(lon2 - lon1)
    
    a = math.sin(dphi/2)**2 + \
        math.cos(phi1)*math.cos(phi2)*math.sin(dlambda/2)**2
    
    return 2*R*math.atan2(math.sqrt(a), math.sqrt(1 - a))/1000

# %%
# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect("./Resources/Tanzania_Water_Pump.db")
water_df = pd.read_sql_query("SELECT * from pump_it_up_training_set", con)

con.close()

# Create a combined column with lat/lon and drop long where 0
water_df['longitude'] = water_df['longitude'].astype(float)
water_df['geo_loc'] = water_df[['latitude','longitude']].values.tolist()

# View df
water_df
# Out:
#           id amount_tsh date_recorded             funder gps_height  \
# 0          0        0.0    2012-11-13              Tasaf          0
# 1          1        0.0    2011-03-05              Shipo       1978
# 2          2        0.0    2011-03-27               Lvia          0
# 3          3       10.0    2013-06-03    Germany Republi       1639
# 4          4        0.0    2011-03-22               Cmsr          0
# ...      ...        ...           ...                ...        ...
# 59395  74240        0.0    2013-03-22       World Vision       1183
# 59396  74242        0.0    2011-04-12             Danida          0
# 59397  74243        0.0    2012-11-13  Ministry Of Water       1188
# 59398  74246       50.0    2011-03-07              Ruthe       1428
# 59399  74247       50.0    2013-02-16            Mission        965
#
#           installer  longitude   latitude               wpt_name num_private  \
# 0             TASAF  33.125828  -5.118154                Mratibu           0
# 1             SHIPO  34.770717  -9.395642                   none           0
# 2              LVIA  36.115056  -6.279268                Bombani           0
# 3               CES  37.147432  -3.187555         Area 7 Namba 5           0
# 4              CMSR  36.164893  -6.099289                Ezeleda           0
# ...             ...        ...        ...                    ...         ...
# 59395  World vision  37.007726  -3.280868  Upendo Primary School           0
# 59396        DANIDA  33.724987  -8.940758            Kwa Mvulula           0
# 59397        Hesawa  33.963539  -1.429477      Kwa Wambura Msege           0
# 59398         Ruthe  35.630481  -7.710549                   none           0
# 59399           DWE  35.432998 -10.639270            Kwa Mapunda           0
#
#        ... quality_group      quantity quantity_group                source  \
# 0      ...         milky        enough         enough          shallow well
# 1      ...          good        enough         enough          shallow well
# 2      ...          good  insufficient   insufficient           machine dbh
# 3      ...          good        enough         enough                spring
# 4      ...          good           dry            dry          shallow well
# ...    ...           ...           ...            ...                   ...
# 59395  ...          good  insufficient   insufficient  rainwater harvesting
# 59396  ...          good        enough         enough                 river
# 59397  ...          good        enough         enough                  lake
# 59398  ...          good           dry            dry                spring
# 59399  ...          good           dry            dry                 river
#
#                 source_type source_class              waterpoint_type  \
# 0              shallow well  groundwater                    hand pump
# 1              shallow well  groundwater                    hand pump
# 2                  borehole  groundwater  communal standpipe multiple
# 3                    spring  groundwater           communal standpipe
# 4              shallow well  groundwater                    hand pump
# ...                     ...          ...                          ...
# 59395  rainwater harvesting      surface           communal standpipe
# 59396            river/lake      surface           communal standpipe
# 59397            river/lake      surface  communal standpipe multiple
# 59398                spring  groundwater           communal standpipe
# 59399            river/lake      surface           communal standpipe
#
#       waterpoint_type_group    status_group                      geo_loc
# 0                 hand pump  non functional    [-5.11815407, 33.1258283]
# 1                 hand pump      functional   [-9.39564152, 34.77071669]
# 2        communal standpipe      functional   [-6.27926803, 36.11505595]
# 3        communal standpipe      functional   [-3.18755455, 37.14743219]
# 4                 hand pump  non functional   [-6.09928949, 36.16489341]
# ...                     ...             ...                          ...
# 59395    communal standpipe      functional   [-3.28086824, 37.00772596]
# 59396    communal standpipe      functional   [-8.94075788, 33.72498733]
# 59397    communal standpipe  non functional   [-1.42947691, 33.96353891]
# 59398    communal standpipe  non functional   [-7.71054858, 35.63048144]
# 59399    communal standpipe  non functional  [-10.63927029, 35.43299843]
#
# [59400 rows x 42 columns]

# %%
# Custom apply function for finding 3 closest city distance and population
def compare_distance_all(ref, city_df):
    
    # use GPS coordinates of current water table and all Cities to calc distance
    city_df['distance'] = city_df['geo_loc'].apply(haversine,args=(ref,))
    
    # Sort a subset dataframe by distance ascending
    sorted_cities = city_df[['distance','population']].sort_values(by=['distance']).iloc[:3]
    
    # Slice custom values for the desired position
    city1 = sorted_cities.iloc[[0]]
    city1.columns = ['distance1','population1']
    
    city2 = sorted_cities.iloc[[1]]
    city2.columns = ['distance2','population2']
    
    city3 = sorted_cities.iloc[[2]]
    city3.columns = ['distance3','population3']
    
    city_series = [city1['distance1'].values[0],city1['population1'].values[0],
                  city2['distance2'].values[0],city2['population2'].values[0],
                  city3['distance3'].values[0],city3['population3'].values[0]]

    # Return as series so it can add a new column
    return pd.Series(city_series)

# %%
# Add the three closest cities to the dataframe
water_df[['distance1','population1',
            'distance2','population2',
            'distance3','population3']] = water_df['geo_loc'].apply(compare_distance_all,
                                                            args=(city_pop_df,))

water_df
# Out:
#           id amount_tsh date_recorded             funder gps_height  \
# 0          0        0.0    2012-11-13              Tasaf          0
# 1          1        0.0    2011-03-05              Shipo       1978
# 2          2        0.0    2011-03-27               Lvia          0
# 3          3       10.0    2013-06-03    Germany Republi       1639
# 4          4        0.0    2011-03-22               Cmsr          0
# ...      ...        ...           ...                ...        ...
# 59395  74240        0.0    2013-03-22       World Vision       1183
# 59396  74242        0.0    2011-04-12             Danida          0
# 59397  74243        0.0    2012-11-13  Ministry Of Water       1188
# 59398  74246       50.0    2011-03-07              Ruthe       1428
# 59399  74247       50.0    2013-02-16            Mission        965
#
#           installer  longitude   latitude               wpt_name num_private  \
# 0             TASAF  33.125828  -5.118154                Mratibu           0
# 1             SHIPO  34.770717  -9.395642                   none           0
# 2              LVIA  36.115056  -6.279268                Bombani           0
# 3               CES  37.147432  -3.187555         Area 7 Namba 5           0
# 4              CMSR  36.164893  -6.099289                Ezeleda           0
# ...             ...        ...        ...                    ...         ...
# 59395  World vision  37.007726  -3.280868  Upendo Primary School           0
# 59396        DANIDA  33.724987  -8.940758            Kwa Mvulula           0
# 59397        Hesawa  33.963539  -1.429477      Kwa Wambura Msege           0
# 59398         Ruthe  35.630481  -7.710549                   none           0
# 59399           DWE  35.432998 -10.639270            Kwa Mapunda           0
#
#        ...              waterpoint_type waterpoint_type_group    status_group  \
# 0      ...                    hand pump             hand pump  non functional
# 1      ...                    hand pump             hand pump      functional
# 2      ...  communal standpipe multiple    communal standpipe      functional
# 3      ...           communal standpipe    communal standpipe      functional
# 4      ...                    hand pump             hand pump  non functional
# ...    ...                          ...                   ...             ...
# 59395  ...           communal standpipe    communal standpipe      functional
# 59396  ...           communal standpipe    communal standpipe      functional
# 59397  ...  communal standpipe multiple    communal standpipe  non functional
# 59398  ...           communal standpipe    communal standpipe  non functional
# 59399  ...           communal standpipe    communal standpipe  non functional
#
#                            geo_loc  distance1 population1  distance2  \
# 0        [-5.11815407, 33.1258283]  35.033967    145292.0  43.859263
# 1       [-9.39564152, 34.77071669]   5.169916     46724.0  42.274055
# 2       [-6.27926803, 36.11505595]  27.054749      5527.0  34.494481
# 3       [-3.18755455, 37.14743219]  21.108603     22839.0  27.433508
# 4       [-6.09928949, 36.16489341]  15.549644      5527.0  30.011861
# ...                            ...        ...         ...        ...
# 59395   [-3.28086824, 37.00772596]   2.722825     22839.0  19.945148
# 59396   [-8.94075788, 33.72498733]   4.651106     12219.0  24.688760
# 59397   [-1.42947691, 33.96353891]  19.803600    121119.0  37.506370
# 59398   [-7.71054858, 35.63048144]   9.882770    111820.0  44.921236
# 59399  [-10.63927029, 35.43299843]   7.192216     19472.0  24.220603
#
#       population2  distance3 population3
# 0         32900.0  65.659579     15320.0
# 1         19040.0  51.339210     15168.0
# 2         11840.0  37.477470     10000.0
# 3        156959.0  38.571507     18726.0
# 4         11840.0  42.023175     10000.0
# ...           ...        ...         ...
# 59395     18726.0  23.792744      9568.0
# 59396     10318.0  26.972198     10642.0
# 59397     16376.0  40.691637     10550.0
# 59398     29193.0  57.908190     18010.0
# 59399    126449.0  45.514102     22155.0
#
# [59400 rows x 48 columns]

# %%
# Export to CSV with merged supplemental data
water_df.to_csv("./Resources/water_pump_closest_cities.csv")

# %%
# Import the supplemneted CSV into the SQLlite database

# load data
df = pd.read_csv('./Resources/water_pump_closest_cities.csv')

# strip whitespace from headers
df.columns = df.columns.str.strip()

con = sqlite3.connect("./Resources/Tanzania_Water_Pump.db")

# drop data into database
df.to_sql("Water_Pump_Status_Complete", con, if_exists='replace')

con.close()
# Out:
# C:\Users\kenww\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %% [markdown]
# ## Prep Tanzania Water Pump Training Dataset

# %%
# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect("./Resources/Tanzania_Water_Pump.db")

train_values_df = pd.read_sql_query("SELECT * from Water_Pump_Status_Complete", con)
train_values_df = train_values_df.set_index("id").drop(['index'],axis=1)

train_labels_df = pd.DataFrame(train_values_df['status_group'])
train_values_df = train_values_df.drop(['status_group','Unnamed: 0'],axis=1)

con.close()

# Verify that result of SQL query is stored in the dataframe
train_values_df
# Out:
#        amount_tsh date_recorded             funder  gps_height     installer  \
# id
# 0             0.0    2012-11-13              Tasaf           0         TASAF
# 1             0.0    2011-03-05              Shipo        1978         SHIPO
# 2             0.0    2011-03-27               Lvia           0          LVIA
# 3            10.0    2013-06-03    Germany Republi        1639           CES
# 4             0.0    2011-03-22               Cmsr           0          CMSR
# ...           ...           ...                ...         ...           ...
# 74240         0.0    2013-03-22       World Vision        1183  World vision
# 74242         0.0    2011-04-12             Danida           0        DANIDA
# 74243         0.0    2012-11-13  Ministry Of Water        1188        Hesawa
# 74246        50.0    2011-03-07              Ruthe        1428         Ruthe
# 74247        50.0    2013-02-16            Mission         965           DWE
#
#        longitude   latitude               wpt_name  num_private  \
# id
# 0      33.125828  -5.118154                Mratibu            0
# 1      34.770717  -9.395642                   none            0
# 2      36.115056  -6.279268                Bombani            0
# 3      37.147432  -3.187555         Area 7 Namba 5            0
# 4      36.164893  -6.099289                Ezeleda            0
# ...          ...        ...                    ...          ...
# 74240  37.007726  -3.280868  Upendo Primary School            0
# 74242  33.724987  -8.940758            Kwa Mvulula            0
# 74243  33.963539  -1.429477      Kwa Wambura Msege            0
# 74246  35.630481  -7.710549                   none            0
# 74247  35.432998 -10.639270            Kwa Mapunda            0
#
#                          basin  ... source_class              waterpoint_type  \
# id                              ...
# 0              Lake Tanganyika  ...  groundwater                    hand pump
# 1                       Rufiji  ...  groundwater                    hand pump
# 2                  Wami / Ruvu  ...  groundwater  communal standpipe multiple
# 3                      Pangani  ...  groundwater           communal standpipe
# 4                  Wami / Ruvu  ...  groundwater                    hand pump
# ...                        ...  ...          ...                          ...
# 74240                  Pangani  ...      surface           communal standpipe
# 74242                   Rufiji  ...      surface           communal standpipe
# 74243            Lake Victoria  ...      surface  communal standpipe multiple
# 74246                   Rufiji  ...  groundwater           communal standpipe
# 74247  Ruvuma / Southern Coast  ...      surface           communal standpipe
#
#        waterpoint_type_group                      geo_loc  distance1  \
# id
# 0                  hand pump    [-5.11815407, 33.1258283]  35.033967
# 1                  hand pump   [-9.39564152, 34.77071669]   5.169916
# 2         communal standpipe   [-6.27926803, 36.11505595]  27.054749
# 3         communal standpipe   [-3.18755455, 37.14743219]  21.108603
# 4                  hand pump   [-6.09928949, 36.16489341]  15.549644
# ...                      ...                          ...        ...
# 74240     communal standpipe   [-3.28086824, 37.00772596]   2.722825
# 74242     communal standpipe   [-8.94075788, 33.72498733]   4.651106
# 74243     communal standpipe   [-1.42947691, 33.96353891]  19.803600
# 74246     communal standpipe   [-7.71054858, 35.63048144]   9.882770
# 74247     communal standpipe  [-10.63927029, 35.43299843]   7.192216
#
#       population1  distance2  population2  distance3 population3
# id
# 0        145292.0  43.859263      32900.0  65.659579     15320.0
# 1         46724.0  42.274055      19040.0  51.339210     15168.0
# 2          5527.0  34.494481      11840.0  37.477470     10000.0
# 3         22839.0  27.433508     156959.0  38.571507     18726.0
# 4          5527.0  30.011861      11840.0  42.023175     10000.0
# ...           ...        ...          ...        ...         ...
# 74240     22839.0  19.945148      18726.0  23.792744      9568.0
# 74242     12219.0  24.688760      10318.0  26.972198     10642.0
# 74243    121119.0  37.506370      16376.0  40.691637     10550.0
# 74246    111820.0  44.921236      29193.0  57.908190     18010.0
# 74247     19472.0  24.220603     126449.0  45.514102     22155.0
#
# [59400 rows x 46 columns]

# %%
#create an integer lookup for the status group
dict = {
    "functional":0,
    "functional needs repair":1,
    "non functional":2
}

# %%
# convert dates from object to datetime
train_values_df['date_recorded'] = pd.to_datetime(train_values_df['date_recorded'])

# %%
# for testing, fillNA with "OTHER" or zero
for col in train_values_df.columns:
    
    if train_values_df[col].dtype == "object":
            train_values_df[col] = train_values_df[col].fillna("Other")
            
    elif train_values_df[col].dtype == "int64":
        train_values_df[col] = train_values_df[col].fillna("0").astype('int64')
        
    elif train_values_df[col].dtype == "float64":
        train_values_df[col] = train_values_df[col].fillna("0").astype('float64')

# %%
# Generate categorical variable list
txt_cols = train_values_df.dtypes[train_values_df.dtypes == "object"].index.tolist()

# %%
# Check the number of unique values in each column
train_values_df[txt_cols].nunique()
# Out:
# funder                    1898
# installer                 2146
# wpt_name                 37400
# basin                        9
# subvillage               19288
# region                      21
# lga                        125
# ward                      2092
# recorded_by                  1
# scheme_management           12
# scheme_name               2697
# extraction_type             18
# extraction_type_group       13
# extraction_type_class        7
# management                  12
# management_group             5
# payment                      7
# payment_type                 7
# water_quality                8
# quality_group                6
# quantity                     5
# quantity_group               5
# source                      10
# source_type                  7
# source_class                 3
# waterpoint_type              7
# waterpoint_type_group        6
# geo_loc                  57520
# dtype: int64

# %%
many_uniques = ['funder','installer',
                'subvillage','lga','ward', 'scheme_name']

# Determine which values to replace
bucket_df = train_values_df.copy()

for i in many_uniques:
    list_value_counts = bucket_df[i].value_counts()
    
    filter_value = list_value_counts.quantile(0.95)
    
    replace_list = list(list_value_counts[list_value_counts < 100].index)
    
    for j in replace_list:
        bucket_df[i] = bucket_df[i].replace(j,"Other")
    
    print(f"completed {i}")
# Out:
# completed funder
# completed installer
# completed subvillage
# completed lga
# completed ward
# completed scheme_name

# %%
# Check the number of unique values in each column after bucketing
bucket_df[txt_cols].nunique()
# Out:
# funder                      92
# installer                   85
# wpt_name                 37400
# basin                        9
# subvillage                  23
# region                      21
# lga                        116
# ward                        59
# recorded_by                  1
# scheme_management           12
# scheme_name                 33
# extraction_type             18
# extraction_type_group       13
# extraction_type_class        7
# management                  12
# management_group             5
# payment                      7
# payment_type                 7
# water_quality                8
# quality_group                6
# quantity                     5
# quantity_group               5
# source                      10
# source_type                  7
# source_class                 3
# waterpoint_type              7
# waterpoint_type_group        6
# geo_loc                  57520
# dtype: int64

# %%
# drop name and duplicate columns
cleaned_df = bucket_df.drop(['wpt_name','payment_type','quality_group',
                            'quantity_group','source_type',
                            'waterpoint_type_group','date_recorded','geo_loc'], axis=1)

# %%
# Finish ETL process with final load into the SQLite db

con = sqlite3.connect("./Resources/Tanzania_Water_Pump.db")


# drop data into database
cleaned_df.to_sql("Water_Pump_Features_ETL", con, if_exists="replace")
train_labels_df.to_sql("Water_Pump_Labels_ETL", con, if_exists="replace")

con.close()
